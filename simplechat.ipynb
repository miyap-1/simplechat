# %% [markdown]
# <a href="https://colab.research.google.com/github/miyap-1/simplechat/blob/main/simplechat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/keisskaws/simplechat.git
# Out:
# Cloning into 'simplechat'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 123 (delta 41), reused 35 (delta 35), pack-reused 71 (from 2)
# Receiving objects: 100% (123/123), 178.48 KiB | 5.41 MiB/s, done.
# Resolving deltas: 100% (55/55), done.
